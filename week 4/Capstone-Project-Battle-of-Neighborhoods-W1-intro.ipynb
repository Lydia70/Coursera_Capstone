# %% [markdown]
# # Capstone Project: Introduction Battle of the Neighborhoods in Vancouver

# %% [markdown]
# *by Lydia Langbroek*

# %% [markdown]
# This is an introduction to my Capstone Project: The Battle of the Neighborhoods. For this project, I choose the city of Vancouver. This summer, it has been 10 years ago since I have visited Vancouver. It is a very nice place with lots of sightseeings! Vancouver is a safe city with amazing public transportation. Aside from being a nice touristic spot, the city is an excellent liveable city. In my Capstone Project, I start the battle of the neighborhoods in Vancouver. At the end, I conclude which neighborhood in Vancouver is the best neighborhood to live in, considering the average housing prices in neighborhoods, crime rate, and specific amenities in neighborhoods. The target audience will be young people who graduated university, have a good job in the city, and who are about to start a family life.<br>
# <br>
# Having a keen interest in data science, I decided to follow the IBM Data Science track. In the past weeks, I have been equipped with lots of new skills. In this project, I apply various skills I have learned in previous courses. Previous courses have prepared me to use APIs to retrieve data. I will extract the geographical and postal code data from a text file I found at Geo Names. I read the text file and I convert the text file to a csv file. Also, I retrieve data on venues/amenities using the Foursquare API. Finally, I collect data on housing prices and crime data from the Vancouver Open Source Portal, and I collected the Vancouver crime data from the release of Vancouver Police Department (VPD) crime data website. I create maps with the Folium package as we have seen in the data visualization course.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Introduction and Business Problem

# %% [markdown]
# According to the results of the Economist Intelligence Unit survey 2019, Vancouver is one of the best liveable cities worldwide. Vancouver ranked 6th of the cities that were included within the survey. Factors included in the survey are living standards, crime, infrastructure, access to education and healthcare, and political and economic stability.
# The City of Vancouver scores high on safety. Also, the city has amazing public transport; bus lines, passenger ferries, and sky trains makes it extra convenient to get around without taking the car. Public transit fares are not really expensive. Aside from having great public transport, the city has both great employment opportunities and lots of activities to undertake in your spare time. Its location is perfect because of its close proximity to the ocean and mountains. <br>
# <br>
# Because of the popularity of the city and high demand of dwellings, the property price increases. People often move to another city for employment reasons. Also, people who graduated school/ university and are about to start a family may be looking to purchase a house. Safety and an affordable living quarter with good amenities nearby are important to consider where to move. Aside from having a good job after graduating school/ university, you want your kids to grow up in a good and safe neighborhood! Therefore, the main question in this research is: What is the best neighborhood to live in?

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![IMG_1070copy.jpg](attachment:IMG_1070copy.jpg)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### This is the end of the introduction section. Enjoy reading my project!
